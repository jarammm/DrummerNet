# %%
import glob

pths = glob.glob("results/temp_exp1/*pth")
pths
# Out:
# ['results/temp_exp1/items_144375.pth',
#  'results/temp_exp1/items_4186875.pth',
#  'results/temp_exp1/items_21875.pth',
#  'results/temp_exp1/items_8369375.pth',
#  'results/temp_exp1/items_4375.pth',
#  'results/temp_exp1/items_13125.pth',
#  'results/temp_exp1/items_83125.pth',
#  'results/temp_exp1/items_271250.pth',
#  'results/temp_exp1/items_8750.pth',
#  'results/temp_exp1/items_17500.pth',
#  'results/temp_exp1/items_1050000.pth',
#  'results/temp_exp1/items_30625.pth',
#  'results/temp_exp1/items_26250.pth',
#  'results/temp_exp1/items_2095625.pth',
#  'results/temp_exp1/items_39375.pth',
#  'results/temp_exp1/items_529375.pth',
#  'results/temp_exp1/items_35000.pth',
#  'results/temp_exp1/items_52500.pth']

# %%
import os

for pth in pths:
    it = int(pth.split("_")[-1].split(".")[0])
    os.system(f"python test.py \
        --input_wav_path ../data_evals/BDT_DRUMS/audio/4376.wav \
        --checkpoint_path {pth}\
        --output_audio_path test/sample4376pth{it}.wav \
        --output_midi_path test/sample4376pth{it}.mid \
        --sound_font ~/Downloads/FluidR3_GM/FluidR3_GM.sf2 \
        --exp_name test -ld spectrum --metrics mae")
# Out:
# Add arguments..
# 입력 인자: Namespace(exp_name='test', kernel_size=3, num_channel=50, scale_r=2, activation='elu', n_layer_enc=10, n_layer_dec=6, sparsemax_type='multiply', conv_bias=False, sparsemax_lst=64, recurrenter='three', batch_size=32, loss_domains=['spectrum'], n_mels=None, learning_rate=0.0004, metrics=['mae'], source_norm='sqrsum', l1_reg_lambda=0.003, n_cqt_bins=12, compare_after_hpss=False, eval=False, resume=False, resume_num='', input_wav_path='../data_evals/BDT_DRUMS/audio/4376.wav', checkpoint_path='results/temp_exp1/items_144375.pth', output_audio_path='test/sample4376pth144375.wav', output_midi_path='test/sample4376pth144375.mid', sound_font='/Users/seola/Downloads/FluidR3_GM/FluidR3_GM.sf2')
# 악기 소스 로딩...
# DrummerNet 모델 생성 중...
# | With a sampling rate of 16000 Hz,
# | the deepest encoded signal: 1 sample == 64 ms.
# | At predicting impulses, which is done at u_conv3, 1 sample == 1 ms.
# | and sparsemax_lst=64 samples at the same, at=`r` level
# ...
